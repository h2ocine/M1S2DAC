# %% [markdown]
# ## --- Generate text with a recurrent neural network (Pytorch) ---
# ### (Mostly Read & Run)
#
# The goal is to replicate the (famous) experiment from [Karpathy's blog](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
# To learn to generate text, we train a recurrent neural network to do the following task:
#
# Given a "chunk" of text: `this is random text`
#
# the goal of the network is to predict each character in **`his is random text` ** sequentially given the following sequential input **`this is random tex`**:

# %% [raw]
# Input ->  Output
# --------------
# T    ->    H
# H    ->    I
# I    ->    S
# S    ->    " "
# " "  ->    I
# I    ->    S
# S    ->    " "
# [...]

# %% [markdown]
# ## Load text (dataset/input.txt)
#
# Before building training batch, we load the full text in RAM

# %%
# !wget https://thome.isir.upmc.fr/classes/RITAL/input.txt
# Out:
# --2024-03-01 12:46:56--  https://thome.isir.upmc.fr/classes/RITAL/input.txt
# Resolving thome.isir.upmc.fr (thome.isir.upmc.fr)... 134.157.18.247
# Connecting to thome.isir.upmc.fr (thome.isir.upmc.fr)|134.157.18.247|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.1’
#
# input.txt.1         100%[===================>]   1.06M  2.66MB/s    in 0.4s
#
# 2024-03-01 12:46:57 (2.66 MB/s) - ‘input.txt.1’ saved [1115394/1115394]

# %%
! pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %%
import unidecode
import string
import random
import re
import torch
import torch.nn as nn

all_characters = string.printable
n_characters = len(all_characters)

file = unidecode.unidecode(open('./input.txt').read()) #clean text => only ascii
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 1115394

# %% [markdown]
# ## 2: Helper functions:
#
# We have a text and we want to feed batch of chunks to a neural network:
#
# one chunk  A,B,C,D,E
# [input] A,B,C,D -> B,C,D,E [output]
#
# Note: we will use an embedding layer instead of a one-hot encoding scheme.
#
# for this, we have 3 functions:
#
# - One to get a random str chunk of size `chunk_len` : `random_chunk`
# - One to turn a chunk into a tensor of size `(1,chunk_len)` coding for each characters : `char_tensor`
# - One to return random input and output chunks of size `(batch_size,chunk_len)` : `random_training_set`

# %%
import time, math


#Get a piece of text
def random_chunk(chunk_len):
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]


# Turn string into list of longs
def char_tensor(string):
    tensor = torch.zeros(1,len(string)).long()
    for c in range(len(string)):
        tensor[0,c] = all_characters.index(string[c])
    return tensor


#Turn a piece of text in train/test
def random_training_set(chunk_len=200, batch_size=8):
    chunks = [random_chunk(chunk_len) for _ in range(batch_size)]
    inp = torch.cat([char_tensor(chunk[:-1]) for chunk in chunks],dim=0)
    target = torch.cat([char_tensor(chunk[1:]) for chunk in chunks],dim=0)

    return inp, target

print(random_training_set(10,4))  ## should return 8 chunks of 10 letters.
# Out:
# (tensor([[94, 17, 18, 28, 94, 29, 17, 10, 29, 94],
#         [94, 24, 15, 75, 96, 44, 94, 29, 17, 18],
#         [29, 27, 18, 10, 21, 94, 13, 10, 34, 75],
#         [54, 77, 96, 55, 17, 14, 27, 14, 94, 10]]), tensor([[17, 18, 28, 94, 29, 17, 10, 29, 94, 51],
#         [24, 15, 75, 96, 44, 94, 29, 17, 18, 23],
#         [27, 18, 10, 21, 94, 13, 10, 34, 75, 96],
#         [77, 96, 55, 17, 14, 27, 14, 94, 10, 27]]))

# %% [markdown]
# ## The actual RNN model (only thing to complete):
#
# It should be composed of three distinct modules:
#
# - an [embedding layer](https://pytorch.org/docs/stable/nn.html#embedding) (n_characters, hidden_size)
#
# ```
# nn.Embedding(len_dic,size_vec)
# ```
# - a [recurrent](https://pytorch.org/docs/stable/nn.html#recurrent-layers) layer (hidden_size, hidden_size)
# ```
# nn.RNN(in_size,out_size) or nn.GRU() or nn.LSTM() => rnn_cell parameter
# ```
# - a [prediction](https://pytorch.org/docs/stable/nn.html#linear) layer (hidden_size, output_size)
#
# ```
# nn.Linear(in_size,out_size)
# ```
# => Complete the `init` function code

# %%
import torch.nn.functional as f

class RNN(nn.Module):

    def __init__(self, n_char, hidden_size, output_size,rnn_cell=nn.RNN):
        """
        Create the network
        """
        super(RNN, self).__init__()

        self.n_char = n_char
        self.hidden_size = hidden_size
        self.output_size = output_size

        #  (batch,chunk_len) -> (batch, chunk_len, hidden_size)
        self.embed = nn.Embedding(n_char, hidden_size)

        # (batch, chunk_len, hidden_size)  -> (batch, chunk_len, hidden_size)
        self.rnn = nn.RNN(hidden_size, hidden_size)

        #(batch, chunk_len, hidden_size) -> (batch, chunk_len, output_size)
        self.predict = nn.Linear(hidden_size, output_size)

    def forward(self, input):
        """
        batched forward: input is (batch > 1,chunk_len)
        """
        input = self.embed(input)
        output,_  = self.rnn(input)
        output = self.predict(f.tanh(output))
        return output

    def forward_seq(self, input,hidden=None):
        """
        not batched forward: input is  (1,chunk_len)
        """
        input = self.embed(input)
        output,hidden  = self.rnn(input.unsqueeze(0),hidden)
        output = self.predict(f.tanh(output))
        return output,hidden

# %% [markdown]
# ## Text generation function
#
# Sample text from the model

# %%
def generate(model,prime_str='A', predict_len=100, temperature=0.8):
    prime_input = char_tensor(prime_str).squeeze(0)
    hidden = None
    predicted = prime_str+""
    # Use priming string to "build up" hidden state

    for p in range(len(prime_str)-1):
        _,hidden = model.forward_seq(prime_input[p].unsqueeze(0),hidden)

    #print(hidden.size())
    for p in range(predict_len):
        output, hidden = model.forward_seq(prime_input[-1].unsqueeze(0), hidden)
                # Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        #print(output_dist)
        top_i = torch.multinomial(output_dist, 1)[0]
        #print(top_i)
        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        prime_input = torch.cat([prime_input,char_tensor(predicted_char).squeeze(0)])

    return predicted

# %% [markdown]
# ## Training loop for net

# %%
def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

###Parameters
n_epochs = 20000
print_every = 100
plot_every = 10
hidden_size = 100
lr = 0.005
batch_size = 16
chunk_len = 80

####

model = RNN(n_characters, hidden_size, n_characters) #create model
model_optimizer = torch.optim.Adam(model.parameters(), lr=lr) #create Adam optimizer
criterion = nn.CrossEntropyLoss() #chose criterion

start = time.time()
all_losses = []
loss_avg = 0


def train(inp, target):
    """
    Train sequence for one chunk:
    """
    #reset gradients
    model_optimizer.zero_grad()

    # predict output
    output = model(inp)

    #compute loss
    loss =  criterion(output.view(batch_size*chunk_len,-1), target.view(-1))

    #compute gradients and backpropagate
    loss.backward()
    model_optimizer.step()

    return loss.data.item()



for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set(chunk_len,batch_size))  #train on one chunk
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(generate(model,'Wh', 100), '\n')



    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
#  3s (100 0%) 2.5452]
# Whalelele helerellinooord; hanthes ulethane dre her I mowhel
# Thake s t s e y, ans stendrethe RThay, of
#
#  6s (200 1%) 2.5563]
# Whean mur wtorall n o pry s se INulis blinthe.
# BERO:
#
# KLe
# f,
# The myores r al fagend y the my myothe ou
#
#  9s (300 1%) 2.4562]
# Wheefois by eberer
# Thef ome hist wis at, avere is ids he he s.
# Pano towousat y t:
# VI pthys tisk w chou
#
#  13s (400 2%) 2.5565]
# Whe ar whan, o om in t my l s uthelofond w Lanalice at ghawade tronf anden ve yoromyeay nd h selangay
#
#  16s (500 2%) 2.4996]
# Whar, ourel fal aubese line fou tit foube atrta ner ille hir the wie we hin y, t thive p hey at to ise
#
#  19s (600 3%) 2.4740]
# Whilees,
# Ayomeng be k'd hind ngerefarandous our th heridourrenghanomat IFLOfat merve CLAPETEShe where
#
#  22s (700 3%) 2.4859]
# Whee INGonos, byod oore t o an r bt I k sthintout casheve s hespoorde ay the y, at;
# ALICon:
# MESUSo
#
# An
#
#  26s (800 4%) 2.4893]
# Whacharthathis d hate sut o t burt mapr s I in sthand, aledice gs methtof the, me pin atimiton mesw ad
#
#  29s (900 4%) 2.4634]
# Whead-
# An, bon, tee ute wo ghin m wis d, tharer pea bel; s cow cord mo an:
# Iisur, fof wis en ds the in
#
#  32s (1000 5%) 2.4726]
# Whe t, y f he.
# VAn ke me pea y fothoread th s beshe ait han, befe:
# Fow fferd ced, I he,
# LI'thefrr'l
# Wh
#
#  35s (1100 5%) 2.4389]
# Wha boneare houndr wilsthindwhesenghe ar:
# ARitor, s s wo warerere fad
#
# An thele an; ithe bordin fustha
#
#  39s (1200 6%) 2.5048]
# Whe w but wherise himou wese me hiver non tave bee who shing tlder s matoul ne y me d.
# ASoronour, hour
#
#  42s (1300 6%) 2.5258]
# Whes to mberadit
# LIO:
# Wh thader d h hases ish roronthinond aiowent myouren
# I hingowing.
#
# Be hie withe
#
#
#  46s (1400 7%) 2.4627]
# Whecomy g teen ssthanguthis? t theseare;
#
# And, heed ies
# D:
# Mar, brthe aulyo by fe pr itaburar te ais b
#
#  50s (1500 7%) 2.4915]
# Whies rend s,
# Harat ht?
#
# RYond andser nfand prt t peseanghinge,
# HO: kr, br ay, whou winitoouldsthand y
#
#  53s (1600 8%) 2.4465]
# Whenoushor.
#
#
# An sher o wed allor be-s o bemeno sthers
# Preily on bure tour ld alourrngemel oren, mou s
#
#  59s (1700 8%) 2.4505]
# Whan the lll INAS:
#
# Whu ind, the.
#
# IUKA: tha tce d'sit s ss t it te bu f nere thowhe peck touke m hino
#
#  4s (1800 9%) 2.4963]
# White, Y:
#
#
# Gof tis tinthise
# HE:
# Had H: ysthe be ce dod nd
# BAnk! sus ther shand?
# Br sthil hee tre l ou
#
#  7s (1900 9%) 2.4324]
# Whenguroulalllie d ou whancarer t t p, t nd. met lor Who herorurowe coweabe thar lat, oure malloucts m
#
#  10s (2000 10%) 2.5160]
# Whase be by.
# Whestho me th catous brd nrand d pl wave t; lovend byourte pegrd soou s or an uneayo' mer
#
#  14s (2100 10%) 2.4647]
# Whed wit bes g tyounce yo, fast en, cous mpor t dens theeead 'd.
# Thive d he aslde IN is by th m, me s
#
#  17s (2200 11%) 2.4961]
# Whr aind frsino igavito tharlos d your ange,
# LYo f re breat hit rkn fa s gerd fitheas t st d rt se me
#
#  20s (2300 11%) 2.4393]
# Whake un ais thou.
# LONThande tor st,
# INureve than s len ve IN:
# Gr ochou fo,
# MENowen omis amis
# ARYo th
#
#  23s (2400 12%) 2.4218]
# Whinsstit isis thers f IEENoundgrofou fl tan t faren sorod hariare.
# HINI d t le d wiston hare's mondea
#
#  27s (2500 12%) 2.4547]
# Whe thaliou my ath wis whe han:
# Favend m me uthee y ge, mard tore t toro w ich f nof metand ivinkiteno
#
#  30s (2600 13%) 2.4715]
# Whe
# Huse sisig wheindit wesishances. lir:
#
# BRCENE llour tin, thoress our d me
#
# IO:
#
# Wak f e merend wou
#
#  33s (2700 13%) 2.4941]
# Wh n te d m tould LL:
# BERpre
# Wh, wiver lly be o.
# K:
# Thimen d cer sinofil wano he ad ms hif ay,
#
# CAnco
#
#  37s (2800 14%) 2.5306]
# Wheis the, tro thest sethoull y wat n ind no on's amowin s.
# Whe ke he woust hendall yote, ba yote tano
#
#  41s (2900 14%) 2.4799]
# Whit sprd wis , bliloupreerat sthalounour nou
# Asthatie thinot:
# The fis.
# METhise br tan hend thint blen
#
#  44s (3000 15%) 2.4957]
# Whilipr tas ilneret se ore shen;
# Thiout pe gha s hayonouse the mes,
# Fin ther
# HEMalls and pathe wis ank
#
#  47s (3100 15%) 2.4701]
# Whe hthid pr ve
# Hef y berd be s plll perst inousane Isid,
# Wheve ho ou I ace aroigis
#
# HESthepous t by t
#
#  50s (3200 16%) 2.4923]
# Wheleand ar nan t lly.
#
# INES:
# Bes four S:
# Wathand in t Ifand in me ut my'e, wilind thamere t pinthorth
#
#  54s (3300 16%) 2.4868]
# Whomime ad t r whim me ithay t alllas D:
# ARD my thourerthand ath;
# D:
# TARI s thit os icothe lis ono d o
#
#  57s (3400 17%) 2.4049]
# Wh t fillese idad t thor pars ownte dl bor pof blllfer tl f t d be chaly penety te hoshe mot bemy,
# Gon
#
#  0s (3500 17%) 2.4804]
# Whantthat I far y me; I my I myoulouty y teathary INTha cer t CAst s we met CENBy istham me finow wice
#
#  4s (3600 18%) 2.5265]
# Wh inte dourongard thimo y beautheallubewie, he by, d d l y s nss thethen adumy e tce fot ourre bulllo
#
#  7s (3700 18%) 2.4673]
# Whedeghod ks.
#
# Sedil Byewer th'doyoond tar, allly ICMasthandisot has.
#
#
# Y: ofende ayor l n
#
# ce serers
#
#  10s (3800 19%) 2.4350]
# Whis?
# Vons
# NI ur Rout,
# NClllan m chelllls!
# Anerf men I nges asencesu s th mallan ry, ng n cenotithunnd
#
#  13s (3900 19%) 2.5272]
# Whe thare my awiee me IOn and we os ore men:
#
# Atinde,
# Wit wit amond, ang mathir wh w thisteavens cofor
#
#  17s (4000 20%) 2.4931]
# Whenthis s nd mer, fangesw an t tis TESindstlfad angot wen if t Whoun sthe d sainouly fet o had roker
#
#  20s (4100 20%) 2.4351]
# Whis ou hindimmy sis kimor hue hon cono t as, ingth f idoun He t woulanccous an l, ay st stheday s:
# Wh
#
#  23s (4200 21%) 2.4912]
# Wheanghys
# Wis the an heror iencave meldy t s
# ARKI'st,
# NIORGHes yoind thaigorarthe d s,
# m OLOxit adeayo
#
#  26s (4300 21%) 2.4899]
# Whithell I rieeary is,
#
# Weru mive tharsse m s be cisul le ghee blllder he o t y hen f f ELalle wisorer
#
#  30s (4400 22%) 2.4515]
# Wheere lt Cotour thakn y th t ty il dsh inout dicherd wh thon, lith t:
# O:
# HENonthoitise were s, be f w
#
#  34s (4500 22%) 2.4611]
# Whe w were s busthe,
# S:
# A ran a Yo land piso wourt:
# Asudn in.
# And theer t alorer ndoust to thicos KI a
#
#  37s (4600 23%) 2.4991]
# Whendawneal yomere u pr ce,
# Bucow d the wenonorearom; tlothalleat may, bevoullithe f tord I torrournde
#
#  40s (4700 23%) 2.4674]
# Whathe,
# Dughelof mbe arshellliche,
# SAS:
#
# The ll tarpesthape y hat be f he s athenthif ING w ath he e-r
#
#  44s (4800 24%) 2.4960]
# Whee dim amy ofin toucheetoounke
# TI geth, t an vemou she d me s se agondearedes, ce
# The:
# Se ied; l t t
#
#  47s (4900 24%) 2.4573]
# Whilaldo MIf thoretesh itherfe d wenannd as ay inor, hy ble h wis anthonemyo de, d we lllooowo enyoull
#
#  50s (5000 25%) 2.4077]
# Whertear,
# CHe wh knds
# As ha nuse and andsat a hew thert ar A heandille?
#
#
#
# '
#
#
#
# Ine ut thonou t! pe ar
#
#  54s (5100 25%) 2.4526]
# Whathor ld che al, Whe andiloous thate mo ts s s thar t kengh bonit I ben
#
#
#
# ICHe dlshrend w chared pl
#
#  57s (5200 26%) 2.4490]
# Whachalar bengr w'e hild G nes l shom ncellit th fotore att we the d---cupoorm;
# Beseso se at y t m me
#
#  0s (5300 26%) 2.4739]
# Whane.
# Whert ay he plofas no ter orere then t.
# ICENors g m lkserreany hengus are sw s wit nown
# Thame h
#
#  3s (5400 27%) 2.5043]
# Whe. any he, cro hy menouton fouremoanor f mper sowindene fond te anep l meventheran cif he fe ore t t
#
#  7s (5500 27%) 2.5236]
# Wher, d,
# Cl thed s'd ind tho he be s thene arashorthaveyo fow.
# A:
# HO:
#
# Yarirhmey;
#
# Toou pe t are tt:
# I
#
#  10s (5600 28%) 2.4813]
# Wh;
# The cou we go ofeve I the helllis hot d fre bou w.
# Gred tourel llsours f t he, ce, inereco fove th
#
#  13s (5700 28%) 2.5549]
# Wh lous sour themello urers f, f yoshe, ithaiss ter ond wilind, oved he or sishin agest, pe a the dowi
#
#  16s (5800 28%) 2.5402]
# Whearyounderdstan in, hof.
# ERou thar dr, pat tislichithar t ELI ther al fetalyoul whin, sthathelor' ul
#
#  20s (5900 29%) 2.4531]
# Whanthe he:
# Thel celllour o t te t?
# T:
# FLAS:
# LIORenepilean m wis lthar yitillleathet foffore ain t t t
#
#  23s (6000 30%) 2.4912]
# Wh lalond if the and areareas ar fou I h,
# MI wisthasof comeinsie inde n the II hithilatoug wounthof he
#
#  26s (6100 30%) 2.4901]
# Whe your t t llere hagh uk gem t CHeespay icofure.
# Pr hicurave fut wer torerte gle w hecatting then 'l
#
#  30s (6200 31%) 2.4650]
# Whes trthee sonoupo du helf t bu herr w me atoushithais t s, wanoONCHove ton'd the se be wise ull ther
#
#  33s (6300 31%) 2.4742]
# Whe hirerd he t age therueriler g?
# PETHEO:
# PELEOMPES:
# FLORUSS:
# NThesingghincar!
# JUS:
#
# An, d p t hoof d
#
#  36s (6400 32%) 2.4467]
# Wh hamo thowerrls w Indor inch t ve LTh an thr u in ices I berer s I in;
#
# Y f olth harth nd s frit and
#
#  39s (6500 32%) 2.5176]
# Wh fowilel E:
# Doongo ERLORule uin mee st cr-
# This lle s, and o bly, IVI Noond ry thord thelll'th her c
#
#  43s (6600 33%) 2.4718]
# Whe, te iu te lde can myanerener thand mefrr iase,
# Whe he ike bousthond to h wider.
#
#
#
#
#
#
# PENCone toup
#
#  46s (6700 33%) 2.4104]
# Whe.
# BUTherenor wan
# Hascke than ththe
# Pry m t my, foutet s hares st sthy witrehithas isanor w ay res a
#
#  49s (6800 34%) 2.4845]
# Wherid wie g our w thusiof ge y, thoour;
# Son t ois ind wid Corepan cingo'Th k im ce I tre bimyor athld
#
#  52s (6900 34%) 2.4226]
# Whizenourdouse me allealave.
# I t ke tonnile marey net me t meayoon wos
# CHI y.
# TENCENGou, umure war mot
#
#  56s (7000 35%) 2.5676]
# Why the hy h s s 's ARERI sinow'thels bararithintie, athesienotho arave sice, he aca g s nd wiveallor
#
#  59s (7100 35%) 2.4613]
# Whelimel fis t baver tiver hanthe f s.
# ARYokerithout my l stherderofour ghanol thy w ce, a nd, hinghe
#
#  2s (7200 36%) 2.4524]
# Whe tofobr h nd f t e wie ts, s! ve ARENG ghy io INas s ginthod so t my CKAn,
#
# Mathe ose habre m f She
#
#  5s (7300 36%) 2.4795]
# Whar t gr, pe mellourd anor aresthe cof ge hey.
#
# NIN he lyof hall R:
#
#
# My:
# S:
# Whour the ared thatour s
#
#  9s (7400 37%) 2.4541]
# Whay and thioven th,
# Prilllllllice pind at at her st IOr mare y onkeraby y h ime the tis bou s o he:
# R
#
#  12s (7500 37%) 2.5177]
# Whe ys ethepe ty tre atho ths te had inoremeathald blou, the menorer, sille.
# Gowanous baviod mel t ale
#
#  15s (7600 38%) 2.4789]
# Whothon the.
# Prove telathechou.
#
# G bre meas s heangrsere fanip;
# NGontindind, hiliswengmo skngbe th w c
#
#  19s (7700 38%) 2.5595]
# Whito.
# Bull pit ir,
# Toryot minchint aimbe oo-metir t wis m r fo's,
# Litheowe y tontoutowatangous thil f
#
#  22s (7800 39%) 2.4191]
# Whis w alonithil it mereso shy!
# RERIse rlar n ilen.
# If I grth the thit t
# Gorit:
# MI t n s thinis mfor t
#
#  25s (7900 39%) 2.4193]
# Whingand arshinthies m fars harand forn shthe fis at dishase decour sothast me t:
# Veir I war adisptho
#
#  28s (8000 40%) 2.4801]
# Whe theny thodoull berds horisin:
# To st thig ou ishiveay moft, nghacerersarco peseare he me.
# RYofourar
#
#  32s (8100 40%) 2.4983]
# Wh watowhititheasiere n hathan d, nd, iry t y t thy t reat mis h,
# O:
#
# Why, sis te oure war ayenor s te
#
#  35s (8200 41%) 2.4440]
# Whenould, the, pr f cen lle we. t:
# KIVI ha ispead tomous s gind ind thit helono an CAngow at tha the h
#
#  38s (8300 41%) 2.4107]
# Whe fegothat fang sthaish se do er t
#
#
#
# Frrend hee, wistan sicrpond my hes hashath imy hthicesspea o c
#
#  41s (8400 42%) 2.4403]
# Whe s I h youe th ke.
# Tonthe them trem t, lon.
# My at ith t, lld E:
# Cond heng heyoothauthe ce hat let,
#
#  45s (8500 42%) 2.4894]
# Wherve w by bavearendis athee bok---fay, wo ure t we sengaroussin hin:
# ORare d angongistes hinther g f
#
#  48s (8600 43%) 2.4264]
# Wher th t te nd, ted f y wotrs we ofthe;
# NGUS:
# Gonge whor beruray ait on athelit th bong Heliendou ot
#
#  51s (8700 43%) 2.4528]
# Where ay ar agis d h trd s wre atou; semnout h me anas.
# Whinorut arero.
# Cout be ce
# Thourerd d ien, hin
#
#  54s (8800 44%) 2.4556]
# Whakinth, tr thitoff at t aind cllly soseed tt me In s f atlord irotharesh as.
# Wivarerindy he?
# I whan
#
#
#  58s (8900 44%) 2.5051]
# Whemor aven woourothard sughe r gharelou, po be y ca str L:
# Ifourse.
# Powou kig ang an ken hth atin;
# LL
#
#  1s (9000 45%) 2.3999]
# Whathetes thes han torighanth,
# Mar o, mer m ree t,
# I nd eay t
# US: lathare m stove t n, y the ss
# Mothar
#
#  4s (9100 45%) 2.4542]
# Whoof il t wainoullara we, ou itce wicopoprithathod bifoupuey ad ff nstose ho theoff an hatee tone s y
#
#  8s (9200 46%) 2.4549]
# Whome and aler an whe.
# The bl; atowithake t cur he wo linithininthathese chenn.
#
# ANThintor,
# CHanomerd
#
#  11s (9300 46%) 2.3645]
# Whirearyoker.
# HORAMouget weak l bemave te gh to fod
#
# ARUCH:
# Wh der dive ar:
# Ay V:
# Theld y t ce V ay in
#
#  14s (9400 47%) 2.5012]
# Whoragota the bld.
# The is winco a st sou an:
# I's th cowre s bupeembest hatin rd e ave a t pou y sht, t
#
#  17s (9500 47%) 2.4325]
# Wheathe is yo bes thas bito s loutss hy the the foragare mmy it isthaspo prthathepanghind he we;
#
# He a
#
#  21s (9600 48%) 2.4584]
# Whe, ghey be astharivey stalarves m d gen ghe myoro d wicoryot wigod thidseande t men s y bo e t who o
#
#  24s (9700 48%) 2.5353]
# Whedan.
# BENont ce paraiteaver tovishe fan'litise skin mouthen s y tathaist thend wnd fe,
# ME:
# Ifor heel
#
#  27s (9800 49%) 2.4185]
# Wht.
# IO: a tharn mourinod t t cou tht ineeldy ve hars henoul sant.
# Yo the n byond, t thin, ino opicous
#
#  31s (9900 49%) 2.4468]
# Whaiehaf wore ir arenghequs wn, ars sot bowhes
# Bure he.
# Myou inousthin:
# We blatowhisthank p, theagothe
#
#  34s (10000 50%) 2.4506]
# Whitithat d mofoly s s
#
# Anold thy nthatit aler m withe bly ay
# Se d t amererour sheil! anammpoe our win
#
#  37s (10100 50%) 2.5022]
# Whee ged by t heansigre TYothe ue hod th
# Baneaingend ave pe nertoulll t!
# LO, thesonof ppee win:
# LORILI
#
#  41s (10200 51%) 2.4317]
# Wharild se ys, d is anothou me m ammandowhofor the fathingof ly, men foucere avenwiseat isear
# IFR:
#
# So
#
#  44s (10300 51%) 2.4634]
# Wherstr llath, tholle wimicard chese ase t shave rte:
#
#
# I llan an neist, mele Pagr ho fit idooure owe
#
#  47s (10400 52%) 2.4861]
# Whegrcou, mer ond
#
#
# TIS:
# An my thioknthandonomearer
#
# TI' wist:
# RUCouras helll fe;
# O:
# F I s is botoke h
#
#  51s (10500 52%) 2.4426]
# Whan the mpele Buas dseco wir ton t frour,--blinerend has?
#
# A:
# I'thincheaned t wisand rorallive.
# Til w
#
#  54s (10600 53%) 2.4425]
# Wh
# He a le wit mam mpll p th nd, me je it yose t tomat thy d, t lige mom botheamyoulisthis Routhe tell
#
#  57s (10700 53%) 2.4972]
# Wh mered I y D:
# LLI'd,
# None caitofomalwh incous ldour p;
# Th,-d it or ivel yes me
# Ar,
#
# Wathelyoulll hin
#
#  0s (10800 54%) 2.4912]
# Whowarullof ay theis thale pr sthe d sthinetorsthinothand thacours chal my my basid at shiler te, l, d
#
#  4s (10900 54%) 2.5004]
# Whasthay bllo arnothe s t foung hat an mo IS:
# Cou maso ar s d myse ken se f plll ol dind h,
# RDULAR:
#
#
#
#
#  7s (11000 55%) 2.4978]
# Whin, ll cousthe we belad lands bo n I isenof fur tleck t y she t fed y, my t t,
#
# NI t f ouchesto
# MAnd
#
#  10s (11100 55%) 2.4432]
# Whin was hetor
# S:
#
# WARD d thoucend E se spthe; onore thoulith I kis d othep wiratto theds belou'Toup a
#
#  14s (11200 56%) 2.4706]
# Whalime winend t meno within by cath thithan heth byod somopry histhe;
#
# KENAndaple malllay en tish mit
#
#  17s (11300 56%) 2.4715]
# Whes wit se wis
#
#
# Whokerchat wim sfize as we bl he Whas, ges f whees spanouris.
# Shappour.
# Se beean bac
#
#  20s (11400 56%) 2.4420]
# Where gie of as har THe d the tovis.
# Anchity, ithese!
# O:
# I g th ad houn s taitears t theavete; d fere
#
#  23s (11500 57%) 2.4605]
# Whenorend d heas waly aperacas th owange he w e t le my wo arouroulets y kisomayouthete.
# T:
# FRUEvat f
#
#  27s (11600 57%) 2.4887]
# Whif st beald h,
# D s ssoy mearthe dinghef winins s be word,
# KERLESe thathe lthe y soues the and me tor
#
#  30s (11700 58%) 2.4868]
# Whee lis ies ngaror n mo bill y wifthertharsangre alsstizere hell, alar'd s:
#
# CO:
#
# BUCEOFou bousthe an
#
#  33s (11800 59%) 2.5351]
# Whe s ffr ace n niveris tomar mi'sede
# WI hous r mome!
#
# SI othat l rin ald ake suringe tis tim arous,
# T
#
#  36s (11900 59%) 2.4902]
# Wheroongeano pendo blenstad apo-he head t ite te t this oreesol tr tad poncoun pe p sce t, wid t thito
#
#  40s (12000 60%) 2.4745]
# When:
# Yorden the livane s, o s therers IClo lor m s.
# Yo eite
# Iso, ntha t o. d; pilordin h, masthelovet
#
#  43s (12100 60%) 2.4625]
# What dathave ts winoure, u wity d de san wilimemy g s.
#
# LARDASThend reameree msthald chando hal le l k
#
#  46s (12200 61%) 2.4669]
# Whind h y I an bedo Soshatharlen thar wourery iches hend westha th looungas me l BICo bllss thandero w
#
#  49s (12300 61%) 2.4482]
# Whoitan, ssstecese; trs s a had thinernd igatomess wipr st l lat
# NI d sowis,
# BURIO:
# Clal wailliowe our
#
#  52s (12400 62%) 2.4244]
# Whesersutheritour I cat ticay s orithe merventind fat and
# ANI llearg y mengok I ho ieverueras d ckerea
#
#  55s (12500 62%) 2.4243]
# Whangndincidot th yolarat h mor:
#
# Yofris atht toinor arcosayoulit be macein g macrimanle fofruthin,
# We
#
#  59s (12600 63%) 2.5282]
# Wheereisthel f sor br he otoss tarethistoure Serps mofere nd, is
# PEe asome t ize an lly I all, thepach
#
#  2s (12700 63%) 2.4851]
# Whit buge he wot lllldighot hethin st ntre cknt hathe t!
# Wha are;
# CEO:
# ARCOrior d cor ckere I l,
# Gopan
#
#  5s (12800 64%) 2.4307]
# Wh yoon'd n the yor yougere that hoffondstret hend ne athan sin se tarwntunotwave, fanon d thowhe for.
#
#  8s (12900 64%) 2.5008]
# Who Re f aus by, d f pe,
# Tore f nge ofle n risate
#
#
# Myoro aisoush ENGourenomitharoror, ckise g, mes fr
#
#  12s (13000 65%) 2.4673]
# Wheeronou t l wie t shar ofusend ce, andaves
#
# ARowid pe d wats trs ar pp!
# CHO hellf pom o his t wo w M
#
#  15s (13100 65%) 2.4584]
# Wheanchenove anthe CEENEERINTho thy; thexthee pr; tw! tharithote
# Bondighe ilou wid Is w bene co edo av
#
#  18s (13200 66%) 2.4534]
# Whenol s be llline y w a harith t toly ath arsurthond;
#
# ARie l, s yoturer it f thoulakis he paghomedo
#
#  21s (13300 66%) 2.4194]
# Whey thesavenckerierendoon mondelise re ou pes gl foune t t t he ar w'l st yoryof y d'teler.
#
#
# I sle a
#
#  25s (13400 67%) 2.4766]
# Whessinonerer thespe.
# She d, theedere ld,
#
# Couche te al l y RO:
# Clilsour il GSClo lyowhar t?
# SAng l s
#
#  28s (13500 67%) 2.4467]
# What;
#
# I youco hepp, nonot I l hoth,
# I t tho pthorend:
#
#
#
# ARDrnemusheale m l:
# DE wine atelathillithe y
#
#  32s (13600 68%) 2.4934]
# Whe ilome, comu, tou IO:
# I binth mes a sen thace t, o:
# GLORGBue hiedeatend t peres sthinswove ed mer d
#
#  35s (13700 68%) 2.4855]
# Whalare ch an topthenor thocound pe thalld chan goorthemyomis chees m'd m wothe woou thoud r ge h cand
#
#  38s (13800 69%) 2.4738]
# Wh he m'd disthame;
# I thothats ivelee f tont y s mullmak meand we t be t atal lerd m toune teay, shore
#
#  42s (13900 69%) 2.4694]
# Whetelownonknthein melakilan be st hemedoror wou t howhe ouppower e, s;
# Hestu ndealyourarin han!
# Th ar
#
#  45s (14000 70%) 2.4373]
# Whed thes m,
# K: mend ot thathave drdeay an'lou?
#
# My the whondericthoure n it arreves t mboubu we meren
#
#  48s (14100 70%) 2.4898]
# Wherurermy arisher se anowhany f l ailde ang nt an stcou byord cofoun n;
# DUFafou shay m LAD wis;
# HIENo
#
#  52s (14200 71%) 2.4886]
# Whtitheadigisspawinoon t as yor ceat y dey tcothaceshor we ld thenthe hean the avethifa he t tofrpr se
#
#  55s (14300 71%) 2.4986]
# Whine me the y llol, thy t story u't.
# Andy m ishe bupof sour, w berist maldind sowand t she.
#
#
#
# I:
#
# Wh
#
#  58s (14400 72%) 2.4451]
# Whend ther sino blime I mend r Yol y shaveighien t isthariu hor, mer s the t walf y as,
#
# Ca an lle t t
#
#  1s (14500 72%) 2.4777]
# Whare seved hof wefondinue g y frsh cre qucamy ur se anghinine wit m, g O:
# Ancole wis, athind ler ked:
#
#  5s (14600 73%) 2.4554]
# Whe he llisthe tothelich puswe w oum n BI rouf My is, stowe, f fase whenshe de ayouecrerdilll ly aswis
#
#  8s (14700 73%) 2.4608]
# Wherin.
#
# Whinessext s BALO, be ad y, y d nor, t conk d ofo EO:
# Sced llllin Wine oret s; whent your S:
#
#
#  11s (14800 74%) 2.4355]
# Whase
# A:
# Touce allif wistemathyono arithe
# Hext.
# Wen wint th bece houcow t Preagove brvim se athieristo
#
#  14s (14900 74%) 2.4694]
# Whe ke nousalurs Isiou ddelithase pllod ved ard se nd are inoe te thithtsuthe suro?
# Hoarireey h he al
#
#  18s (15000 75%) 2.4744]
# Whele he bend t!
# Buindit s ll, t m it m
# TE:
# Towig.
# Anoe s t t bur t:
# wice hanctat, gim tour.
# HAUCLan i
#
#  21s (15100 75%) 2.4903]
# Whary ther:
# OUK: s ad ond
# Fr fo ard tave the h?'s f pe yo schestowopof y eaist y o bour le llancat I'd
#
#  24s (15200 76%) 2.4705]
# Whond l be, thin ofee
# Mas.
# MEMIORDitomerdanous:
# Le fay me I ofacove'd;
#
# Couse win th t sean.
# Pr p th.
#
#
#  27s (15300 76%) 2.4491]
# Wh heset mat, s an.
# S:
# Ofo pe we thever bs RUCHA oor y m h I llou te ws h brr alounglifar:
#
#
#
#
#
# Sedsar
#
#  31s (15400 77%) 2.4535]
# Whifo kea thisan trou weat I's sthethe, coul ld the;
# Aned se.
# S:
# BRYOLY ld'lyous nd t stheshy the stha
#
#  34s (15500 77%) 2.4519]
# When s, mald!
# Thathare an asusthithe win wis pe l th cethindin his IOrepio had asppralare asshimy d bl
#
#  37s (15600 78%) 2.4723]
# Wh, beit; MET:
# Of but ms he howin thato l;
# Ango hes sof:
# RE:
# Y he t tousishe y ad ovis; tound le t te,
#
#  40s (15700 78%) 2.4668]
# Whereareng 's gr f pin h; the NGouseen t y, Congrme h sine be homes wowisan ser ilyou foutt, oman vero
#
#  44s (15800 79%) 2.4282]
# Whelt
# Tout,
# TERYowen t t thad h the astig lave, l ane mby met pil t f mave the ppr:
#
# Thend lto wiou di
#
#  47s (15900 79%) 2.4849]
# Whanat whingale thand aty.
#
# Sofime alouarsthancune ton isheres man, chans thevelimaser's ind thessoine
#
#  50s (16000 80%) 2.4749]
# Whe s
# DUCANI oulor bend centhathor frint at my che ofour ovithous
# S:
# CEXESSINGor D mice thear horinsou
#
#  53s (16100 80%) 2.4273]
# Wh's herothyse herith, lyoiges, herote, wis, toncer
#
# Thapabe e.
# MANEThat s thath t fopeth at th y an f
#
#  57s (16200 81%) 2.4971]
# Whityomungomes y, ackemafed publy ter onghe anowighath mfatoure t I iseng t:
# Hisnderd wes lly d t cars
#
#  0s (16300 81%) 2.5262]
# Wharch;
# ORin theshrd ss t me south laie se fow fou ses
# Fer allopert d ce dy fin pr Paitis t nd eand an
#
#  3s (16400 82%) 2.4329]
# Whang,
# CHavemy, t br geneas y
#
# INGHes thaurour.
#
# ME:
#
# Thedsas y,
#
#
#
# uthe CLOLAnth owach th o wase te i
#
#  7s (16500 82%) 2.5079]
# Whe thisaire.
#
#
# STowhf t wive thtis y orous atoowid kereracis irewin hiengn:
# ADid loupour s is t HAns
#
#  10s (16600 83%) 2.4472]
# Whe,
# I ar mutorend and th-
# Wher t he f thale palembaig hert bre thandvino air athid ber r he t if ay o
#
#  13s (16700 83%) 2.4908]
# Whares:
# Wou an andinde boan ofot th h mack.
# PRFouse arsut and t:
#
# Teoorendan t whis whoon hopard sere
#
#  16s (16800 84%) 2.4796]
# Whsthe
# Hes wise bererard
# TENENou, t pourldupousif pre rdy sshit S:
# KENothe.
# TUTh ten ld kellereanor l
#
#  20s (16900 84%) 2.4785]
# Wheald, INI thawirinor bund, sind sthatit ngorur r le hiny
# MEdr imeve aike t gre hisheele be sheforesh
#
#  23s (17000 85%) 2.4550]
# Whenou he achul n; cr l d s marer arshe herinend che st ter inchadilirdend t th t ate, ghemee, ovinewi
#
#  26s (17100 85%) 2.4894]
# Whe.
# CHAY ger as fothain joreaniderindit th souse's ither sishirde he y BADUCHA: Ifoke learan heast ag
#
#  29s (17200 86%) 2.4449]
# Whinthind aceefllper t mind ary ber the t Whe ainkint send?
#
# Prexino,
# TRe t the sou y es bemy no se to
#
#  33s (17300 86%) 2.4533]
# Whad lt nthe llenthenthta ovent it ur'd Ineathe h sth s f:
#
# Ald, d
# Thedincrr ke he!
#
#
# The s; as, sper
#
#  36s (17400 87%) 2.4886]
# Whitas t ENG mant at heica,
# ARICENTh thifimooud he mars ghat:
# TE:
#
# Whicalel mo therethermean
#
# I teis o
#
#  39s (17500 87%) 2.4809]
# Whe ou ck, biny f I e angr chas ieathin lenda wo be I his ano, t Sill fr he havayoond IESTous inthe ar
#
#  42s (17600 88%) 2.4681]
# Wherthe ameatclll lares h Douresheng buthe henos r t
# Bulile,
# Tigl nd theave fishe scoud,
# Andeach whe h
#
#  45s (17700 88%) 2.4490]
# Whe y hisestheey,
# Sine f to ovemy, methe
# bar sale cker mereap t y te bes areeles an thisthuer ded r'd
#
#  49s (17800 89%) 2.4920]
# Whir tik m todor, toyopt:
# Fot atod
# d t old
# Mallllanck tout t hy
# CENGornthyoke, gusend,
# Mou bemy obld h
#
#  52s (17900 89%) 2.4163]
# Wheves llourawed owatie R:
# Wh m ceshad me
# Asthare fane I be mour wor tie f t aveas withano keres h, m
#
#  55s (18000 90%) 2.3843]
# Whishight bs wrire u ll;
# MI nth witobinde hond w, bereladend or wie Ansesuroulll trctord t thaus hatth
#
#  59s (18100 90%) 2.4949]
# Whane ime mene.
# Wh mand me os pe
#
# ARThtos ISea ICor o at h ms han whe IONGr orend bougo mar me t jur m
#
#  2s (18200 91%) 2.4840]
# Wh,
# Baneith aleabeay,
#
# Wheprd thangindrowere urnd thal a nd ngs irretheke m thase; ror stht yof al an:
#
#  5s (18300 91%) 2.4395]
# Wh'lo conth ENI fe an s knchease usseourous ict t s: we h stlar, d we bupenl thaw aithere hatis hiom s
#
#  8s (18400 92%) 2.4715]
# Whar Heasine, imane g d s t isusetowir k is t aickey to s d t
# Sorn the
#
# A:
# We!
# Inonore tet-f hat n f t
#
#  11s (18500 92%) 2.4450]
# Wh
# Weapote t teel ou mut
# Whe? herknalyome te
# BAld cowind thare isef ' te des mspot ss
#
# NCENowadour
# Co
#
#  15s (18600 93%) 2.4829]
# Wh VIUK:
# BR:
# KI s ircathen o s I therse mand d
# Andw ld ive yos w, akn dlenghitsthe bas;'lllastheldeal
#
#  18s (18700 93%) 2.4612]
# Whands, ars t st'
# Tonerer stouran s y hawo thathis che.
# THAs, t INCOFo t he s sout d t ins:
# Maistoute.
#
#  21s (18800 94%) 2.4813]
# Whe,
# CKIne we ithe come lie
# Sorin'st hare pesthaplendorouthe,
#
# O:
# PE: ck st f tit ckey
# Ther, fithinove
#
#  24s (18900 94%) 2.4944]
# Whay, he m fath n werdine whedr, u t t tor, oude bes tatlt, re e pe s s st gar at he h her itourson in
#
#  27s (19000 95%) 2.4044]
# Whe athirurphe n t s mo dit ineaise ssthe anchathathay there.
# IOMINCHoul ide, ar bend meresored d impt
#
#  31s (19100 95%) 2.3963]
# Wheinooule t ad iman athathan, y me I ho D e, t y ithane NTOrerur d, athiot?
# Thotlcou ayord hed arind
#
#  34s (19200 96%) 2.4488]
# Whe.
# S:
# My s henst
# TII th tee inos, ha iacithese thond thyonsttherve thewerss meanemplle su besoke t t
#
#  37s (19300 96%) 2.4830]
# Whors t townoy ule savon and, ay me heass st g.
# The ves serou one iner llooo memy s ounchioverkery lim
#
#  40s (19400 97%) 2.4584]
# Whe ga y me I, pe tithitherith
# Hes tant athe t aillloo hesor, tlerand halk man d hee fod t,
#
# RYotheth
#
#  44s (19500 97%) 2.4216]
# Whist
# LAUTRONur, he, t dad d
# Myhe 'de or?
# Whe lld g be t,
#
# Wotourtllly womy iousther hat; ot te sh y y
#
#  47s (19600 98%) 2.4920]
# Whande II lve whagr ore,
# AD t bon bead me yond tel, coshar:
# GLUCand--farind t,
#
# cothere thortth ouf th
#
#  50s (19700 98%) 2.4472]
# Whe and o asthte, mout fereinithait tan my ayo wan,
# Thereren t nche he th, thalongbr thoupar at coofon
#
#  53s (19800 99%) 2.4505]
# Whe sein'd
# RKII my wind ngre carrd, at mas t this winerino,
#
#
# Shinofe, fore theansell-bjee all hamolea
#
#  57s (19900 99%) 2.4699]
# Whet t IVI hyo the we toote t; ndsif d:
# I hay therimere mar ie.
# Wh thiseave g by hery sener:
#
# Gon wave
#
#  0s (20000 100%) 2.5454]
# Whetheperomms iur tor nd s angu, oon ca s buratanotind wou won nelanoot t sende'end wan:
# INTENGo hthil

# %% [markdown]
# ## Visualize loss

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

plt.figure()
plt.plot(all_losses)

# %% [markdown]
# ## Try different temperatures
#
# Changing the distribution sharpness has an impact on character sampling:
#
# more or less probable things are sampled

# %%
temps = [1, 0.8, 0.5, 0.3, 0.1]

for temp in temps:
  print(f"temperature = {temp} : {generate(model,'T', 200, temperature=temp)}")
  print("----------------------------------------------------------------")
# Out:
# temperature = 1 : TI wis, isoy y?
# DY:
# Cllouthewnthe-d,
# AMI ir,
# Wh owe a llld avive an doug; me cle fr ha-
# AMowistoftouispry wense,
# Wellinl Whang tillllos ayike, pon Wemarike bee MO:
# found os.
# HAUShamif marsedleso, hig o
# ----------------------------------------------------------------
# temperature = 0.8 : Therowougrarilith a angar
# PRO:
# Pof gore o it lonof tonthed.
#
# I whongouds be ardes t pokerapreithouroshe f t I ptore pan s s arars ashond cheator ace ayonthenour prend dionin dos lpeas areirs aspadre th
# ----------------------------------------------------------------
# temperature = 0.5 : Thore s woroongoure th wit asherind, the ar ind d and theres, are me at mer ands t te ad thard t s s as thit bes the ter s pous pe at y s s s s s s ther t s,
# And there ther'd, ary s tor l s s sered mad
# ----------------------------------------------------------------
# temperature = 0.3 : There athe and t the the the thind mat t s s are thes I are the pre ares he thit and athere thend tous ther s the are the ther s the the s perd and the and, are me athe s and thereres ares anthe and th
# ----------------------------------------------------------------
# temperature = 0.1 : The the the the the the and and the the the and and the the and and the the the the the and the the the the and the the the the the the the the the the the s the the the the the the the the s s the the
# ----------------------------------------------------------------

# %% [markdown]
# ### Improving this code:
#
# (a) Tinker with parameters:
#
# - Is it really necessary to have 100 dims character embeddings
# - Chunk length can be gradually increased
# - Try changing RNN cell type (GRUs - LSTMs)
#
# (b) Add GPU support to go faster

# %%
n_epochs = 20000
print_every = 100
plot_every = 10
hidden_size = 300
n_layers = 5
lr = 0.005
batch_size = 16
chunk_len = 80

model = RNN(n_characters, hidden_size, n_characters, n_layers) #create model
model_optimizer = torch.optim.Adam(model.parameters(), lr=lr) #create Adam optimizer
criterion = nn.CrossEntropyLoss() #chose criterion

start = time.time()
all_losses = []
loss_avg = 0


def train(inp, target):
    """
    Train sequence for one chunk:
    """
    #reset gradients
    model_optimizer.zero_grad()

    # predict output
    output = model(inp)

    #compute loss
    loss =  criterion(output.view(batch_size*chunk_len,-1), target.view(-1))

    #compute gradients and backpropagate
    loss.backward()
    model_optimizer.step()

    return loss.data.item()



for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set(chunk_len,batch_size))
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(generate(model,'Wh', 100), '\n')



    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0


plt.figure()
plt.plot(all_losses)
# Out:
#  7s (100 0%) 2.4776]
# Wherde er ur G ar f ad grarshein anth, athat f alis d bancingour s apour lt?
# TELOKI lod wist cl this u
#
#  13s (200 1%) 2.5074]
# Whesmersthindeat Thatandith s hes s yous fas t,
# F ar ce icouspe te?
#
# O:
# O: thoknd t t torertoumacece s
#
#  20s (300 1%) 2.4963]
# Whot!
# As ave CIS:
# 'rdwre wis teave, ld ce
# NGoos neardoth at any malerdy.
# Ther avere mpt wif whitheard
#
#  27s (400 2%) 2.5552]
# What iatitifo h t,
# Th ave ot nd s fager er y t pe ary ndy; d ss d wane th chat thay d arte t y aththe
#
#  33s (500 2%) 2.5010]
# Whe hyownd th therecunnowathiusedsthen acousty,
# Fer r'ldesau my m mbul a shest,
# O:
# They d. an tr e fou
#
#  41s (600 3%) 2.5230]
# Wh'd thit hen at toubuerer thy Thit, wartangh thathan t t bbicitall and, m mathim ded and, d t
# INoun f
#
#  47s (700 3%) 2.4423]
# Whe; shen he her dad ghouly fe, we d ar htordord;
# re bukechathay hy th w nke thou s chamy ther wif fe
#
#  54s (800 4%) 2.5442]
# Whag d arenenor, go ootooo ms t hit s blo spe borustorsinof o beches tspowhart y ctt daly oris bou wil
#
#  0s (900 4%) 2.4754]
# Whe soms ge st w hand se ald t
# Thanthin ss nd mang buroindot himaren bureid VINICUmeand
#
# HARES:
#
#
# OWe
#
#  8s (1000 5%) 2.4983]
# Whe br s, milis loutoouthesee the ie I in t wiofen her t lord ts ag toof que t l ot te;
# ESTe I'sereeav
#
#  15s (1100 5%) 2.4982]
# Whes:
#
# Ang re pathin:
#
# Rince litomave st peikedear.
# An, itowngubes d poot.
# EDe tire ore
# The tt Pe ifon
#
#  22s (1200 6%) 2.4674]
# Whe or brd tse dee whe, ath eaboou's to, atabeanitotyoose may y t MI mad weny hiowicupphankeeave Lowor
#
#  29s (1300 6%) 2.5087]
# Wheseay bur dil--mere sedom.
# An he r ioureache hen t wishe cen thth y yome far y sereth t romine mario
#
#  35s (1400 7%) 2.4475]
# Whind y coinghe ho ttou alo t we. athere pin whe the
# Whe the y t ar thakithed merilor outthinoureve to
#
#  42s (1500 7%) 2.4738]
# Whames.
# Wyous, p, tis tof as incllanot il'dillin herathavand be br s, f n bet my wan:
# D be n
# deangre b
#
#  49s (1600 8%) 2.5126]
# Whathicon monllir wispor d, ts f favoman am matr od kiteco g t od ad.
# HE:
# RETh are merastilon ll?
# And
#
#  56s (1700 8%) 2.4885]
# Whe t.
# Bu, a, the be I py d
# Thed leand be;
# RThe sthay hean he hare tlint be ghindendomat t cee be blys
#
#  2s (1800 9%) 2.4659]
# Whate I be, fall ar, fusore fr? hourer bresetroueant t wherthipoan to wamiss da I thon I th mer t by d
#
#  9s (1900 9%) 2.4855]
# Whalll
# ARDoos thithe wecove cha lil cealy t'se t he t canof chearis?
# TMoprst
# Of, m I y thingins iching
#
#  16s (2000 10%) 2.4924]
# Whatsur w, t fouaceand oshand my dill.
# doupo tond y nod r athecthe iveset y w yomou merow o'd tha s ye
#
#  23s (2100 10%) 2.4994]
# Whartthan, wio cr s on alll; is fing he avir BYone wnker IOLOLOfe t haks, ndonouanou ans n g tho nSoth
#
#  29s (2200 11%) 2.5396]
# Whill ancken,
# ALety me sly iofrd courd mershan,
# s ur me t ald l.
# Ishoulate mes d mye'dind t pee, an ar
#
#  38s (2300 11%) 2.4999]
# Whe my y,
#
# Anoyou yondis ng hearino m,
# A:
#
# INAnofatome ard bame thond wicing:
# ARNENT:
#
# Yoof t bee RThi
#
#  45s (2400 12%) 2.5061]
# Whl wane m! t migreno it ilend had materd und cte ise,
# Asmes ir k, tsth t rs s. is ur  ma y:
#
# Th tesom
#
#  51s (2500 12%) 2.5223]
# Whor.
# Of et alllyo hou s ve andoushe t ge I arde m; hracath bessthis WABend cthiss has wnd,
# Tome thit
#
#  59s (2600 13%) 2.5263]
# Whellurey nt s tite bat wintht he wo haite.
# Your withave s n my?
# NCHes s k's wougou pagrnghr benge l,
#
#
#  5s (2700 13%) 2.4456]
# Whous woted
# MI th fes t s hagesilo thesoy.
# Thonof le alle ive tharalas the o brthaturs; no bapus the i
#
#  12s (2800 14%) 2.5164]
# Whithend t y as ithee houng oul t.
# 3 caleld ay thatheland telere mer?
# Heyore mof t; sther,
# Whod oomate
#
#  18s (2900 14%) 2.5839]
# Where lkigheeat,
# An mecay KI t cou, t ano bred are.
# Whes ndusorar:
# ARTI ngewhes h he theeavee the hod
#
#  25s (3000 15%) 2.4609]
# Whers ce nthal gn chind iry aviman IS:
# Goto RERDiserin Maveris maigheeprewon in nof I Bes her.
# fours e
#
#  32s (3100 15%) 2.5206]
# Whal, un whed wo ouro?
# Th po re ousofro aitinenonding.
# Thee thy oud w, wo? g Ciringerowithelize IARIUM
#
#  39s (3200 16%) 2.4393]
# Wheepatat ce 'd
# Sherer he afistis tthe thers, hin, matir thir asome gisthar'sathiveandea wh-held avemi
#
#  46s (3300 16%) 2.5180]
# Wh t
# MILAwe se ple t se het ce s ncomard a INDAur the thearino oven mer se t r barore m,
#
# An CORD ce m
#
#  52s (3400 17%) 2.5344]
# Whe ak t r.
#
# Mesind waborin:
# I at anisalland tit hof n t I:
# PENRD t s ine bupeadie ndy wireero m mere
#
#
#  0s (3500 17%) 2.4273]
# Wh! ickiveaven thashe t bor I de he st. mafithepeauthat ourie mof chouche l th d, sthe ll s talo the c
#
#  6s (3600 18%) 2.4641]
# Wh onove wn t yo ng ter yorsig bull fianorr
#
# OMAn gau ag foricu te.
# O:
# Peer ber hat, o f, thot ir wen
#
#  13s (3700 18%) 2.5301]
# Whe;
#
# F m re henn y?
# NGr he ple merere s dinunce.
# I ane y tha me fare?
# TOShe ns dstave, llmp cothe st
#
#  19s (3800 19%) 2.4886]
# Who l le keano thonthalthopparakn ann be an e reacors:
#
# I s d t pimpryo itorca d to y s,
#
# Whou psonord
#
#  26s (3900 19%) 2.4770]
# Whon Hanthe arod wo t Bl t woloun f in ver; no,
# Fou an it sthicano l ginom the An wit NGR:
# N
# BENGom is
#
#  33s (4000 20%) 2.4760]
# Wherand tt ot at mprro paven RK:
# GHARit mme, ald s I asopinte he I f t t sse harrt mathe be t y millf
#
#  40s (4100 20%) 2.5182]
# Whino d,
# ISBun ar ang PENThild oucouneremennt, t ger in s t y tit; youn nd leng be, t ber he tt t gle
#
#  46s (4200 21%) 2.5121]
# Whe n ate outh Yor wawivealichanth f
#
#
# Hate d To shithe ononat ju g o d lll tiseald ng y mantlon h,
# NT
#
#  53s (4300 21%) 2.5181]
# Whind the ply ctreapls brm here ar:
# Anos thar. pethe.
# Hestre CAne wite eereeanorellllarkilat tham,
# Ane
#
#  0s (4400 22%) 2.5405]
# Whefor catothithalle?
#
# Whe thalyonordd, ditheem:
#
# Far shelimare:
# MI vers enck ater arer tareakss fle T
#
#  7s (4500 22%) 2.4676]
# When ten INI ourevertur tor fou t thern'dst horour
#
# 's y lthen youronen me keng then outhenele tre E:
#
#
#  14s (4600 23%) 2.4833]
# Whisio wn o m ter thourint I wisser thengene thecenver, but wings,
#
#
# AUThe che d w be t is f y t tind
#
#  20s (4700 23%) 2.5063]
# Wh we are y hen,
# IINThen ld the ar s
# Th ngen h hey t he simoowarun gout g ghenou prokngl I I gope d t
#
#  28s (4800 24%) 2.5617]
# Whior f ern:
# Inomave te, s f ferasthavous our o tome selousshowht d gro w; aves youn be towhe the sth,
#
#  34s (4900 24%) 2.4639]
# Whe lowoullesprenowithenghanghoreses thele t s tighe tombe fot ofarefanos wore me'de fota me PAnge he,
#
#  41s (5000 25%) 2.4402]
# Whe sons bromoray n, I the stht my IS:
#
#
#
# ARINO:
#
#
# Thart ain ther ss! thabanthar fthis e move.
#
# JUplev
#
#  47s (5100 25%) 2.4994]
# Whad arshe lenass as ll y esponos,
#
# CAndeed n opllllan f be,
# Mage
# QUSThecourores ag by m brinor's s ul
#
#  54s (5200 26%) 2.4648]
# Whisey m blins on werssor singhinor anofis aisthanay athan hin d br we.
# K:
# Whellston;
# Ar ledsees a moo
#
#  1s (5300 26%) 2.4596]
# Wherthe there ave the y,
#
# Haly en be, the the w hare f s; n D d be t hes hig g d, histhe 'doraveren wa
#
#  8s (5400 27%) 2.4862]
# Whe s chot rs it,
# f blain t at:
# VI er benthe oul mee hecotolllly.
# Ind; f, me t, llill, s pr th be arde
#
#  15s (5500 27%) 2.4829]
# Whaly INRe swis kere t s t alalou yorn he.
#
# Tw that
# God cothe h.
#
# OMNourthe,
# Cowiro s.
# ORWan
# PEor mahe
#
#  21s (5600 28%) 2.5082]
# Whenes as.
# PSIO:
# I te an theay illo t th s ds we tee n meateis. my su he ld, stathandest heroupu d Hes
#
#  29s (5700 28%) 2.5138]
# Whe an fase d, o oushele d bs t as me borin,
# MERYof winen sche t the ss theang h the
# MNCE r he w cord;
#
#  35s (5800 28%) 2.5306]
# Whend s are tow, mistin!
# Bupaive d cee the hthean,
# I gherer'dast h l iou ouroupry pre the trreeneseeag
#
#  42s (5900 29%) 2.4498]
# Whe t toreine y mersancrerathino heringrt no whe t ancl me hay at tha anowit t ind goute betr tingh be
#
#  48s (6000 30%) 2.4654]
# Whind thatheverd in
# BENGLLEEORTowouithe thisoule I thil flk, haisthathotherus ind isthy f ar ld dists
#
#  56s (6100 30%) 2.5221]
# Wh E:
# Ha ere ye mathel fama nke han anceag it muthofuron mayond atof,
# O:
# SEY co win, tling, ancong sth
#
#  3s (6200 31%) 2.4759]
# Whit winke se d thal isintous.
# LO brkilf pis s whe, s fowe witho war kig, yothe,
# A she I h s n in ER:
#
#
#  10s (6300 31%) 2.4871]
# Whe gcoult mulde
# BESofoumeld d bes ghathaidorus t buse hisathe wouthe thour ure cone utoir'd, t wouner
#
#  17s (6400 32%) 2.4758]
# Wheouke ie d m wanouge, hilll ithe windungoree!
# MINThotinditatalorene oyoot telead t t wetr a he yome
#
#  24s (6500 32%) 2.5059]
# Whe s ay othitsh, be aiothofomerd. w wicod tt aifesok s g co itonoud s the t thieal ms yowat'd we blle
#
#  31s (6600 33%) 2.4892]
# Wher we se f amyof othisor the Orenorinean outhe aref u dio kssf me his thimad'l f his,
#
# Whe;
# F ind fo
#
#  37s (6700 33%) 2.5016]
# Whyou arplowicke oun t mit thing me m itherile kife ayspod fours kthianouethe thorsered lithake murvet
#
#  44s (6800 34%) 2.5266]
# Why ce pe
# WI S:
# Gok LAs n tin tin
# Th s my tre cel th th nilar d Vis thepooulto methemy f m y w wheale
#
#  50s (6900 34%) 2.4833]
# Whomond ofo thif sind g t s; t matheson sose ondaco acifror h antheatordoro e cou derta
#
# HO:
# Touth to
#
#  58s (7000 35%) 2.4576]
# Whe prou thange coracou house
# We Fom,
#
#
# Wigis t
# Titheandou thin:
# I te ioughe nisthimyoturwhor hond wan
#
#  4s (7100 35%) 2.5434]
# Wh w w, melatht bucuprous s y garif dou s cext theprend tisunoris y pe chal ganthalisithanchanfir wst
#
#  11s (7200 36%) 2.4892]
# Whannousthiey,
# Pughoou hers t,
# As al n o mere: n arallde fftherepoderengor weth PENUS:
# The s aiolio w
#
#  18s (7300 36%) 2.4726]
# Wh an we thr d ty's ate mu ad yse as the as! cid ll,
# Buche ous that Br;
# Tof yorour nate tes f auprdero
#
#  24s (7400 37%) 2.4992]
# Whilve owompomeas larel quechese, be le t usermereay s t mo s arae usel woun d toured oun nd. byo kema
#
#  32s (7500 37%) 2.4651]
# What
# Whend pe t c ar s tcea whet toe wnove sthar idsed, tis itencat t t ththoulke t s at RCHAD s y fu
#
#  38s (7600 38%) 2.4973]
# Whe upre s youshe ldigorlis t m!
#
# TIN:
# Teda aviem weatis foureand d ve vatesend he head heathe I he I
#
#  46s (7700 38%) 2.5313]
# Whell'd, thay ld qupsthis A:
# ARI aid chen antrild gemowathathingore besth MENI n, wedind s be kine oth
#
#  52s (7800 39%) 2.4892]
# Whin s p iru dindr hrad nghar I tloncar sheas; s s nalewhond al minsse he nond Aur foueacethad blaruin
#
#  59s (7900 39%) 2.4852]
# Whe torthor hese s se ICI t be der ir hereand. d beatheg herspo h s thelt anthe our
#
# Pareyorn ce ONRK:
#
#  5s (8000 40%) 2.5218]
# Whathidanckisis, by, he y he heve, ce chinous, y bas meay by we atherareamel y d howind nd IOLI:
# Pry b
#
#  13s (8100 40%) 2.5379]
# Whe my t
#
# LO:
#
# KI s he wrt thee atht stant od cine gaream bouroulyou wicoutchend lot, whillllor pr bat
#
#  19s (8200 41%) 2.4637]
# Whe diathe omer
# CHes,
# Wher d mb folomme bo ake theng inois pr thel t?
# Pour me ther,
# Mond ad ieigheshe
#
#  26s (8300 41%) 2.5383]
# Wh hard nghusishe' betonon nd
#
# Gethe?'T:
# Whind owinsorownthinorounge thand tl a lle ellthinghin's thre
#
#  33s (8400 42%) 2.4897]
# Wh, t thy mad t mes,
# WAng byou t ld
# Plleit akerisckeles, pilat totas.
# Wha menely inoulan, te orarot be
#
#  40s (8500 42%) 2.4807]
# Wharyorincemysuse mary he, corepand t mar:
#
# CESir he.
# We. t t,
# Man angublomat trro
# ble h t s ake r, ce
#
#  47s (8600 43%) 2.5387]
# Whe wales Th n afo bus 'surthe akerd aventot ge eray; l,
#
# IONTINUCENI f meer, oury, bucaye, g; se izet
#
#  53s (8700 43%) 2.5183]
# Whano yourthedlatounde.
#
#
# Fath the t y sthu pre yon'l d he mooor wer ayo was, wathoutund larellld h at
#
#  0s (8800 44%) 2.4372]
# Whistwid S:
# EEN:
#
#
# Tht pand, coomorin perer anor y d theers marron beall muthes mind be ispre pis l y
#
#  7s (8900 44%) 2.5197]
# Whe cucthed har lll.
# To wo, gand.
# SENCK:
# 'd f sisst
# The henoularse in w aved ppl me
# Cay adrs, walloue
#
#  14s (9000 45%) 2.4845]
# Whe ined ave d ous lllo t ors, ENTy o knarer, canousene amy al me an,
# Ofort ano mat tlithere ksthe per
#
#  20s (9100 45%) 2.4706]
# Whthin ge ayorthepserestouslord,
# Ye tr the hand,
#
# S:
# Whe sthene she mend ton d d bl be I'le ond t sin
#
#  27s (9200 46%) 2.4800]
# Whailon t t thild
# Thee, ins bend itrroouce I ththitioro marowald; t a VOf ge
#
# Turer,
# LICENCout che be
#
#  34s (9300 46%) 2.5642]
# Whoou nd h s the whappospp ad sathar wisad!
# DYeafouronerthe of y INAur hin awe chak hy boourit win d m
#
#  41s (9400 47%) 2.4901]
# Whe te.
# NCowith. tit tade. athenous he,-
# Whes
# ARO:
# KENeithand pr; wn tored y me oud, t t nthe lort lld
#
#  48s (9500 47%) 2.5025]
# Whis soresh be ce ay o yo anomeorther kis fon ven.
#
# Thecakisthe thorou,
# Ane heaist wsof can thave a ca
#
#  54s (9600 48%) 2.5330]
# Wh d s ban s co.
# OLes ango be pll te chyot celle ou d ke gl an t thed by d bunde 'd m'e d, she illand,
#
#  2s (9700 48%) 2.5169]
# Why s boulthalurerespoththun we ce tththo n m ng.
# WAboure,
# I this y t yofo wirs pousserd pee tinithe,
#
#  8s (9800 49%) 2.4591]
# Whead
# Thate aind he; he s s turd alomy o me man sthe h gisthanorveator pre spo is thiand cthers toucou
#
#  15s (9900 49%) 2.4650]
# Whrour ver;
# Auid Hent sthadofanche, ke thonou thalerere dirs here
#
# Cimend we nerit mertithind, y g t b
#
#  21s (10000 50%) 2.3895]
# What thathe out to se wipeand f hed be an ht tofodeedes wng me:
# Wh'd wheasoouthee ware youle de INor t
#
#  32s (10100 50%) 2.4442]
# Whin fes whises hon hishechanou, nthe hitense win f aris harord waved mam.
# CLI thtont adind s
# TI aned
#
#  43s (10200 51%) 2.4551]
# Wh wikntinarat wasto tance fangat way tt osor ooorard te be
#
# Wowestreroust pe wime cher, y'd o!
# STharo
#
#  54s (10300 51%) 2.5532]
# Whouring,
#
# F thotra rs
# I ived, f m tal tos ano wemy maly peveaispor wir, g g lut tean s orecans thathi
#
#  2s (10400 52%) 2.4999]
# Wheellyove cacove th an arome ficharsthe, fore athore Burierecooore singenckery thes hewow fene t, cha
#
#  11s (10500 52%) 2.4744]
# Whit houll owinthaishave. ada iveeng se f he t h wear ar hurous seant t ave alavee BI ato fouce thouge
#
#  20s (10600 53%) 2.5088]
# Who s,
# Lis, atathindo hy nenoouandise the llley s ig atind as t t nk th bll br nd that.
# D lf neathe th
#
#  28s (10700 53%) 2.5149]
# Wh s f we.
# Wh?
# Tad we ar aldes
#
# I whis wand bere s haris tou as aru, atowhe CENGoun n llerowaread ant
#
#  37s (10800 54%) 2.4822]
# Wha teldefis h ENownd asthean il tt, do tery,
#
# Gie HAndee mus waten thanot:
#
# And,
# Plad.
# I wishie, wndo
#
#  47s (10900 54%) 2.5531]
# Whand g gemathan ath oursmout t be bed is cu ak f ge! ched, avend or y te we s mbonout boru shad kime
#
#  55s (11000 55%) 2.4888]
# Whe he? st t hay abyo he grve e,
# t ntof l chyomucthee, t'd r thare ctheade w ansthe he t mer se's, tai
#
#  3s (11100 55%) 2.5263]
# Whoomonst dris the; pother s, heshoue d med per thed d ponemyo o?
# GLILagere f my s s et as ds, the he
#
#  11s (11200 56%) 2.5016]
# Whou s beane ofe se stho sethan:
# Be me fom huns wn me the thes hencerr t arur themys torese mar ce,
# Do
#
#  19s (11300 56%) 2.5079]
# Wheancarure air s fis hit al thercou alinond soa wes y qu I y, pison,
# Whasthe o t re te thee bugre by
#
#  26s (11400 56%) 2.5190]
# Whe car a ald tourspll wonghy ma tad n,
# d ore fandese yobles fourind mbeloue its; y erenshau and meean
#
#  35s (11500 57%) 2.4570]
# Wh he ano vere, w ld.
#
# Bere teell ghave ld veiss
# Fowreref teeroo wal l wiang ur,
#
# I y, issiout hassord
#
#  42s (11600 57%) 2.5281]
# Wha nd tusowel w Le BO:
#
# ABI woun, be ape lortho an aurmyourer, to berdo ge atinthan f fabus, tales ba
#
#  50s (11700 58%) 2.4555]
# Whan thenofe meirend mathenr s ilingr? ged mofofo s o t br to the hisenou t mene t s simanithithour wi
#
#  0s (11800 59%) 2.5278]
# Whe wil hered men lorengr myowitopan ty, te d ankend to o w; t atofe t wnwheron y K:
# Tont wan in o ISI
#
#  6s (11900 59%) 2.5781]
# Wherndistoukerou you, icr ou oust ce ir youre ber see ee this d of haigmate arorn y a be t atou too of
#
#  13s (12000 60%) 2.5247]
# Whalldicopane, s wermy the bullll tit h to haran ie hisbelou fo med.
# ABy hend INCHAUCERDUSeraner d kn.
#
#  20s (12100 60%) 2.5411]
# Whousbesayo wat wis mplatheithangr vee
# Souttothenod areak'd, owathathe oe Cangomsorin! wind, ple f sth
#
#  27s (12200 61%) 2.5383]
# Whe le, s th
# Th ustate s thy wedis fot be be bea thed lof sar,
# NDWhed atare y bouche penivesere fapard
#
#  34s (12300 61%) 2.5164]
# Whacero y itobu est ghac by d mande t thisthend t misorere d l d,
# LUSasicavedindod ve ate st sthithay
#
#  40s (12400 62%) 2.4879]
# Whilat l d t Yers wesustithe as we lle thenorende s aviode my m te, t se s, wen s.
# P:
#
# Wing w s w s s'
#
#  48s (12500 62%) 2.4923]
# Whura ait f y ave ithean ainontor there.
# chort'd od be,
#
#
# Thint.
#
# MIZAny:
# Whed, ts d nonde y! t y s th
#
#  54s (12600 63%) 2.5401]
# Whe be er s moroulis, sin:
#
# AUSebuloupper ithanccey terd hathok s t s, s,
#
# Mere.
#
# Su, todon l spomed t
#
#  2s (12700 63%) 2.5122]
# Whepr nd thy l ou f wiepy houraras und te acatenoout fived he y routher ather?
# I iowht wail l t aris c
#
#  8s (12800 64%) 2.4158]
# Wheloue we t kere berds.
#
# CLO:
# JURI:
# STUCanghile y It freneaveastig t he he f,
# GHESS:
# F l core flite v
#
#  15s (12900 64%) 2.4733]
# Whative t wheay the h t pe as s,
# whas.
# Ay,
# Fay,
# Man be, be g be.
# stheariellleanthe
# Whece roond w me th
#
#  21s (13000 65%) 2.5092]
# Whe m he oussershe ontere s malthaille, hand t warithalanedendebur s be y d, lllite an aver I'
# TIItl s
#
#  29s (13100 65%) 2.4219]
# Whathe perdourt te LUnd fas toult theret ocel pprous ve gow te RA:
# We wore chy nstor jouryord t t byou
#
#  35s (13200 66%) 2.4439]
# Whesmenge,
# IONThe de ng m ind t herorar at thente wad omet gre bs t benour as, harald thans tho o teng
#
#  42s (13300 66%) 2.5226]
# Whe brdond f cus ant bery wheree bjule ancondou wh atharan burit 's hare lde cofors e hit my wapooouro
#
#  50s (13400 67%) 2.6159]
# Whangend ar chacinand pl f s:
#
# Ang Con fake ff ten
# Auteland thontll peathor: fry
# PERCEETRII BI he ICO:
#
#  56s (13500 67%) 2.5054]
# Whigutot I honganf h torechey sh thith or wit he lk, areanou th s prfoo chathe t y ourorene is myo nde
#
#  3s (13600 68%) 2.5314]
# Whot f pe LARomes to wile aiou fesge fitour y ngo ts.
# ANIO:
# AThelllffl p--coulletas, he.
#
# I pehenghela
#
#  10s (13700 68%) 2.5227]
# Whers, alof gnder d s?
#
# BI'lllllad as shalolouthe be m ll sind d ar d;
# ANI hapesund aserou d isl o hin
#
#  17s (13800 69%) 2.5015]
# Whathusap I outo t, a m se blerse aplly themaimy y t I the t h come
# Buce t: s ithe, yord
# I I ' s our t
#
#  23s (13900 69%) 2.5425]
# Whe w m, wa ne arlandar, thaniso, bblfal himim de tha per woust ts he, aimell wath PAle daco theay he
#
#  30s (14000 70%) 2.5149]
# Whine bed o ul pou be bremat t ithind:
# M: thue me s the qu hesthire t d so, h pe thomyou llon this.
#
#
#
#
#  37s (14100 70%) 2.4344]
# Whelyifans que bll!
# Sirecathas, bas owouartheen bld these,
# Whe,
# STAnonepanophing y aichringur g t tho
#
#  44s (14200 71%) 2.5007]
# What hinsts ha yor t d RLLENor and heaumelen choonthemensthe alice gat s yof aldswhilof tr t lly wist?
#
#  51s (14300 71%) 2.5592]
# Whee tre ingod l rot:
# O:
# INCENThe thed fe lesou h,
# BELO:
#
# Senopt Ther Yo inondes,
# IUCan mace ando l me
#
#  57s (14400 72%) 2.5332]
# Why yousthent ge ly r, ye wine f LUS:
# As myo iberly.
#
# ce che.
#
# Th hare m; sor burenth, wist r we the b
#
#  5s (14500 72%) 2.5006]
# Whomyoutre tyond th hot ghandisur t,
# Frit the, hind.
# OLUS:
# Whar:
# The aristho.
# Or ous, tlind ldorong g
#
#  11s (14600 73%) 2.4228]
# Who w mayoul y ave me llaveasobower tr'siringithipueale astoue mousthe, t be ys chat mad ou the dothre
#
#  18s (14700 73%) 2.5337]
# Wh hang haspell sis meve hiuper henkto.
#
# Thaimy herndoovenghethad ond, douret t yee oucor athenge'serd
#
#  25s (14800 74%) 2.4622]
# Whe?
# Thmaice be bese he hathe,
#
#
# OFr at masod hans mear bure s.
# OM:
# Thad nd?
# Whare e y BERINI ly an th
#
#  32s (14900 74%) 2.4830]
# Whe heane ht y t arl,
# Fathond me'lur
#
#
#
# TENRGou as he besha lse oo f p be ise you t RO:
# Kas.
# Yondethel
#
#  38s (15000 75%) 2.4878]
# Whecowod whanor y hyous y atind brthe ouene found, yor ce.
# Whe,
# Chedend wiswouthy youn bugooon e
# These
#
#  45s (15100 75%) 2.4941]
# Wher:
# YCAs illo ingof e acof afe prd nsenthe an st sty d meser ond s nk TAR he s; anan!
# An
#
# HEY d d ic
#
#  52s (15200 76%) 2.4743]
# Whad tor banser'sanomyous a the,
# Aneneayorot,
# I amilerund thesouthe seak s the sind s an caprd te, an
#
#  59s (15300 76%) 2.4750]
# Whemanar fashouryout around r-n tofer, RDWesoraren,
# teas dis d s at l t wet anowexp?
# mare mp lain t ho
#
#  6s (15400 77%) 2.5056]
# Wherr tounchamelithide, ait n thelatorar thie y soory f harearethe that h he, padyoff he
# Gomat y be, t
#
#  12s (15500 77%) 2.4924]
# Whemerthit me, thelilareaianee ars whe:
# IENCETo an d.
# Indllin s h ger ber yor mesond, ndind od f wh ne
#
#  20s (15600 78%) 2.4904]
# Whelou my fur ige n ford brst lond went:
#
#
# I t t t.
#
# Ham cora thenksu mingrere llorourifal n:
#
# BRWe ie
#
#  26s (15700 78%) 2.4465]
# Wh; t S:
# Angldsulleche my h'ds banome s wor bod woro oupareabreerll sthit d, menone s
# T:
#
# Lo med te ou
#
#  33s (15800 79%) 2.5153]
# Whowis neledrealt s
# BO,
#
# Fout nn.
# T:
# Cove cornd yor'shaciere d, s hanorit the ffe tond indel weang f w
#
#  39s (15900 79%) 2.4630]
# Wherngrst;
#
# Whe itore brd
# d t sher atown falllemere yeather ng berime lests blll meroristiso laler wis
#
#  47s (16000 80%) 2.4908]
# Whanothaimisono ndepounthisoroth,
# Wh.
# AUSe wan an ys ses ran y in ke. ABICULA:
# APs act thinquly for ow
#
#  53s (16100 80%) 2.5216]
# Whad t ndart amit an! thothoke I pper ous ayeand ar on thit at amiornotul ped tor t s amon t t y my th
#
#  0s (16200 81%) 2.4710]
# Whag
# A:
# ANINICETHAn ithist mo co ine th nthy, is y layond mond n ithoure l co th st sthot ne be mear g
#
#  7s (16300 81%) 2.5088]
# Wheeelinofore l ifelo l find ous fonin hy m ares d, fomyo mys beese beacke; bou y trver de, hond thes
#
#  14s (16400 82%) 2.4711]
# Whanoo hend bucin g,
# HENRII tove be barst t instind h myowk d wigawerur ars d w s f bers beeanor ongab
#
#  21s (16500 82%) 2.5200]
# Whe
# me t beeamuravesan sere nd atather I t the t t e s dst t t chanveavel sere atrountind harencatison
#
#  27s (16600 83%) 2.5336]
# Whak pterurethe, ake t bers yo mencertr.
# An lextanspe, ase we d.
# PRDurs EN:
# Ashie st wrerend, fithalll
#
#  34s (16700 83%) 2.4876]
# Whorinsel.
# Thine be t delle's ththe meo s, whier yomather'de wope e thand I s, I bunolithipowano thit,
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-7efc26fcb0e0> in <cell line: 40>()
#      39
#      40 for epoch in range(1, n_epochs + 1):
# ---> 41     loss = train(*random_training_set(chunk_len,batch_size))
#      42     loss_avg += loss
#      43
#
# <ipython-input-5-aa5cf915a54c> in random_training_set(chunk_len, batch_size)
#      20 def random_training_set(chunk_len=200, batch_size=8):
#      21     chunks = [random_chunk(chunk_len) for _ in range(batch_size)]
# ---> 22     inp = torch.cat([char_tensor(chunk[:-1]) for chunk in chunks],dim=0)
#      23     target = torch.cat([char_tensor(chunk[1:]) for chunk in chunks],dim=0)
#      24
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 80 but got size 79 for tensor number 6 in the list.
