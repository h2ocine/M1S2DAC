# %% [markdown]
# ## Linear + TanH + Linear + Sigmoid

# %%
import sys
sys.path.insert(0, '..')

# %%
from activation import TanH, Sigmoid
from enums import GradientDescentMode
from linear import Linear
from loss import MSELoss
from optimizers import SGD
from sequential import Sequential

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Net module

# %%
def Net (input_size, hidden_size, output_size):
     return Sequential(
        Linear(input_size, hidden_size),
        TanH(),
        Linear(hidden_size, output_size),Sigmoid()
     )

# %% [markdown]
# #### Data

# %%
np.random.seed(42)
n_samples = 1000
X = np.random.randn(n_samples, 2)
W1 = np.random.random((2,10))
W2 = np.random.random((10,1))
y = Sigmoid() ((TanH() ((X @ W1+ np.random.random()))) @ W2 + np.random.random()).reshape(-1)
y = np.where(y >= .5, 1, 0)

X_test = np.random.randn(n_samples//2, 2)
y_test = Sigmoid() ((TanH() ((X_test @ W1+ np.random.random()))) @ W2 + np.random.random()).reshape(-1)
y_test = np.where(y_test >= .5, 1, 0)

# %%
def eval_fn(net, X, y):
    y_pred = net.forward(X).reshape(-1)
    y_pred = np.where(y_pred >= .5, 1, 0)
    return np.where(y_pred == y, 1, 0).mean()

# %%
net = Net(2, 10, 1)

lr = 1e-1
epochs = 10_000
loss = MSELoss()

all_loss, all_loss_valid, all_acc_valid, best_parameters = SGD(
    net,
    loss,
    lr,
    X,
    y,
    epochs,
    GradientDescentMode.BATCH,
    -1,
    eval_fn,
    X_test,
    y_test,
)
# Out:
# Train : -----------------------------------
# Epoch 1000: train loss: 0.021069164341042494 val loss: 0.018480938247415372 val eval_fn: 0.994
# Epoch 2000: train loss: 0.01387435002918009 val loss: 0.012177574770479609 val eval_fn: 0.988
# Epoch 3000: train loss: 0.01094994107280545 val loss: 0.010162391265246928 val eval_fn: 0.984
# Epoch 4000: train loss: 0.009292617596369164 val loss: 0.009302236435837379 val eval_fn: 0.984
# Epoch 5000: train loss: 0.008191790654880094 val loss: 0.008895757590380991 val eval_fn: 0.984
# Epoch 6000: train loss: 0.007391841884533791 val loss: 0.008706537051183214 val eval_fn: 0.984
# Epoch 7000: train loss: 0.006777109829828459 val loss: 0.00863453600882213 val eval_fn: 0.984
# Epoch 8000: train loss: 0.0062866475822156735 val loss: 0.008630363886327045 val eval_fn: 0.984
# Epoch 9000: train loss: 0.005884625138369731 val loss: 0.008666804621591357 val eval_fn: 0.984
# Epoch 10000: train loss: 0.005548212183596416 val loss: 0.008727684940056567 val eval_fn: 0.984
# -------------------------------------------

# %%
plt.plot(all_loss, label='Train loss')
plt.plot(all_loss_valid, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(all_acc_valid, label='Validation acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
net = Net(2, 16, 1)

lr = 1e-1
epochs = 2_000
loss = MSELoss()

all_loss, all_loss_valid, all_acc_valid, best_parameters = SGD(
    net,
    loss,
    lr,
    X,
    y,
    epochs,
    GradientDescentMode.BATCH,
    -1,
    eval_fn,
    X_test,
    y_test,
)
# Out:
# Train : -----------------------------------
# Epoch 200: train loss: 0.046136521916595015 val loss: 0.04545064017828756 val eval_fn: 0.996
# Epoch 400: train loss: 0.031155595614821924 val loss: 0.029366489547884345 val eval_fn: 0.994
# Epoch 600: train loss: 0.024718665616042572 val loss: 0.02263055961215509 val eval_fn: 0.99
# Epoch 800: train loss: 0.021038421038576546 val loss: 0.01892433885523148 val eval_fn: 0.986
# Epoch 1000: train loss: 0.01861854880282302 val loss: 0.01658825239427006 val eval_fn: 0.986
# Epoch 1200: train loss: 0.016882554912131746 val loss: 0.01498510069664048 val eval_fn: 0.986
# Epoch 1400: train loss: 0.015560543029437723 val loss: 0.01381896877858791 val eval_fn: 0.984
# Epoch 1600: train loss: 0.014509770862296524 val loss: 0.012934797562765027 val eval_fn: 0.984
# Epoch 1800: train loss: 0.0136476973469149 val loss: 0.012243769755001063 val eval_fn: 0.984
# Epoch 2000: train loss: 0.012923143003329038 val loss: 0.011691321213537213 val eval_fn: 0.984
# -------------------------------------------

# %%
plt.plot(all_loss, label='Train loss')
plt.plot(all_loss_valid, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(all_acc_valid, label='Validation acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
net = Net(2, 16, 1)

lr = 1e-1
epochs = 200
loss = MSELoss()

all_loss, all_loss_valid, all_acc_valid, best_parameters = SGD(
    net,
    loss,
    lr,
    X,
    y,
    epochs,
    GradientDescentMode.BATCH,
    -1,
    eval_fn,
    X_test,
    y_test,
)
# Out:
# Train : -----------------------------------
# Epoch 20: train loss: 0.16428554141807883 val loss: 0.16339730919434942 val eval_fn: 0.86
# Epoch 40: train loss: 0.12110259179045002 val loss: 0.12230765892873682 val eval_fn: 0.938
# Epoch 60: train loss: 0.0997067407585601 val loss: 0.10111759583343789 val eval_fn: 0.958
# Epoch 80: train loss: 0.08668813582905216 val loss: 0.08786083872101022 val eval_fn: 0.964
# Epoch 100: train loss: 0.0777456181090819 val loss: 0.07857153284202305 val eval_fn: 0.966
# Epoch 120: train loss: 0.07110078308736906 val loss: 0.0715641547057152 val eval_fn: 0.966
# Epoch 140: train loss: 0.06588808784044212 val loss: 0.06600236237521138 val eval_fn: 0.968
# Epoch 160: train loss: 0.06163806609601122 val loss: 0.061425938230786715 val eval_fn: 0.972
# Epoch 180: train loss: 0.05807423794842155 val loss: 0.05756066338356448 val eval_fn: 0.972
# Epoch 200: train loss: 0.05502242012097892 val loss: 0.05423204451548864 val eval_fn: 0.976
# -------------------------------------------

# %%
plt.plot(all_loss, label='Train loss')
plt.plot(all_loss_valid, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(all_acc_valid, label='Validation acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
